# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
import pandas as pd

# %%
from wordcloud import WordCloud, STOPWORDS
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import platform

# %%
cd /content/gdrive/My Drive/Colab Notebooks/smishing/Mecab-ko-for-Google-Colab
# Out:
# /content/gdrive/My Drive/Colab Notebooks/smishing/Mecab-ko-for-Google-Colab

# %%
! bash install_mecab-ko_on_colab190912.sh

# %%
cd /content/gdrive/My Drive/Colab Notebooks/
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %%
import re
from konlpy.tag import Kkma

# %%
data = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/산은_앱_리뷰_618개만.csv')
data.shape
# Out:
# (618, 5)

# %%
text = ' '.join(data['리뷰']).replace('.','')

# %%
tokenizer = Mecab()

# %%
tokens = tokenizer.nouns(text)

# %%
words = pd.Series(tokens).value_counts()[:100]

# %%
# 나눔고딕 설치
# !apt -qq -y install fonts-nanum > /dev/null
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumSquareR.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
wordcloud = WordCloud(font_path = '/usr/share/fonts/truetype/nanum/NanumSquareR.ttf',
                         relative_scaling = 0.2,
                         background_color = 'white',
                         ).generate_from_frequencies(dict(words))

# %%
plt.figure(figsize=(12,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
print(' '.join(words.index.tolist()))
# Out:
# 앱 업데이트 은행 로그인 사용 오류 수 지문 플 계좌 인증 등록 거 공인 것 후 로딩 이체 실행 불편 산업은행 번 인식 증서 번호 때 설치 기능 중 일 화면 개선 가능 해결 나 데 무한 게 입력 지원 뱅킹 전 인증서 조회 가입 짜증 송금 버전 이후 이번 개 타행 확인 시간 접속 시 비밀 최악 고객 문제 창 건가요 폰 에러 거래 진행 이용 필요 건 서비스 건지 이전 안드로이드 리뷰 카드 사람 방법 듯 이거 수정 점 속도 부탁 단계 조치 이상 말 하나 신분증 삭제 바이오 업 보안 굿 최고 자체 금융 인터넷 편리 촬영
